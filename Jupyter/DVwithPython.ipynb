# %%
# %pip install -U pip pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -andas (c:\users\jj-pc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\jj-pc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\jj-pc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\jj-pc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages)
# ...

# %%
# %pip install -U pip matplotlib
# Out:
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.1 MB 2.1 MB/s eta 0:00:04
#    ------ --------------------------------- 1.3/8.1 MB 2.3 MB/s eta 0:00:03
#    --------- ------------------------------ 1.8/8.1 MB 2.3 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.4/8.1 MB 2.3 MB/s eta 0:00:03
#    ---------------- ----------------------- 3.4/8.1 MB 2.8 MB/s eta 0:00:02
#    ------------------- -------------------- 3.9/8.1 MB 2.8 MB/s eta 0:00:02
#    --------------------- ------------------ 4.5/8.1 MB 2.8 MB/s eta 0:00:02
#    ------------------------- -------------- 5.2/8.1 MB 2.8 MB/s eta 0:00:02
#    ---------------------------- ----------- 5.8/8.1 MB 2.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.8/8.1 MB 2.8 MB/s eta 0:00:01
# ...

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3]
y = [1,4,9]
z = [10,5,0]
plt.plot(x,z)
plt.plot(x,y)
plt.title("Correlation of y to x")
plt.xlabel("X")
plt.ylabel("y")
plt.legend(["This is xz", "This is xy"])
plt.show()

# %%
sample_data = pd.read_csv("sample_data.csv")
sample_data
# Out:
#    column_a  column_b  column_c
# 0         1         1        10
# 1         2         4         8
# 2         3         9         6
# 3         4        16         4
# 4         5        25         2

# %%
sample_data.column_c
# Out:
# 0    10
# 1     8
# 2     6
# 3     4
# 4     2
# Name: column_c, dtype: int64

# %%
sample_data.column_c.iloc[0]
# Out:
# np.int64(10)

# %%
plt.plot(sample_data.column_a, sample_data.column_c, "o")
plt.plot(sample_data.column_a, sample_data.column_b, "v")
plt.show()

# %%
data = pd.read_csv("countries.csv")

# %%
data
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# ...           ...   ...         ...
# 1699     Zimbabwe  1987     9216418
# 1700     Zimbabwe  1992    10704340
# 1701     Zimbabwe  1997    11404948
# 1702     Zimbabwe  2002    11926563
# 1703     Zimbabwe  2007    12311143
#
# [1704 rows x 3 columns]

# %%
US = data[data.country == "United States"]
US



# data.country == "United States" is truths and falses
# data[truth value]
# Out:
#             country  year  population
# 1608  United States  1952   157553000
# 1609  United States  1957   171984000
# 1610  United States  1962   186538000
# 1611  United States  1967   198712000
# 1612  United States  1972   209896000
# 1613  United States  1977   220239000
# 1614  United States  1982   232187835
# 1615  United States  1987   242803533
# 1616  United States  1992   256894189
# 1617  United States  1997   272911760
# 1618  United States  2002   287675526
# 1619  United States  2007   301139947

# %%
China = data[data.country == "China"]
China
# Out:
#     country  year  population
# 288   China  1952   556263527
# 289   China  1957   637408000
# 290   China  1962   665770000
# 291   China  1967   754550000
# 292   China  1972   862030000
# 293   China  1977   943455000
# 294   China  1982  1000281000
# 295   China  1987  1084035000
# 296   China  1992  1164970000
# 297   China  1997  1230075000
# 298   China  2002  1280400000
# 299   China  2007  1318683096

# %%
import matplotlib.pyplot as plt
import pandas as pd

a = [1,2,3,4,5]
b = [3,4,5,6,7]
plt.plot(a,b)
